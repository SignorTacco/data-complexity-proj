# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd
import numpy
import networkx as nx
import matplotlib.pyplot as plt 
import json
import os
from urllib.parse import urljoin

# %% [markdown]
# ## Extracting Characters information - this is already put into "characters_analysis"

# %%
folder_path = "rickmorty_characters"

if not os.path.exists(folder_path):
    os.makedirs(folder_path)

# %%
# Complete mapped list for the infobox fields
desired_infobox_fields = {
    "SPECIES": "Species",
    "TYPE": "Type",
    "AGE": "Age",
    "AVERAGE LIFESPAN": "Average Lifespan",
    "STATUS": "Status",
    "OCCUPATION": "Occupation",
    "HOME PLANET": "Home Planet",
    "PLACE OF ORIGIN": "Place of Origin",
    "AFFILIATION": "Affiliation",
    "FAMILY": "Family",
    "FIRST APPEARANCE": "First Appearance",
    "FIRST SEEN IN": "First Appearance",
    "VOICE ACTOR": "Voice Actor"
}

# Function to get character links from a given category page URL
def get_character_links(page_url):
    character_links = []
    page = requests.get(page_url)
    soup = BeautifulSoup(page.content, 'html.parser')
    
    # Locate all character links on the page
    for link in soup.select(".category-page__member-link"):
        character_url = urljoin("https://rickandmorty.fandom.com", link.get('href'))
        character_links.append(character_url)
    
    # Find the "Next page" link, if it exists
    next_button = soup.select_one(".category-page__pagination-next")
    next_page_url = urljoin("https://rickandmorty.fandom.com", next_button.get('href')) if next_button else None
    
    return character_links, next_page_url

# Function to extract specific infobox data
def extract_infobox_data(soup):
    infobox = soup.find("aside", {"role": "region"})  # Infobox container
    infobox_data = {field_name: None for field_name in set(desired_infobox_fields.values())}  # Initialize with null values

    if infobox:
        for item in infobox.find_all("div", class_="pi-item"):
            label = item.find("h3", class_="pi-data-label")
            value = item.find("div", class_="pi-data-value")
            if label and value:
                label_text = label.get_text(strip=True).upper()  # Convert label to uppercase for matching
                value_text = value.get_text(strip=True)

                # Check if the label_text is in desired_infobox_fields
                if label_text in desired_infobox_fields:
                    mapped_field_name = desired_infobox_fields[label_text]
                    
                    # Handle "First Appearance" by using the first available match between "FIRST APPEARANCE" and "FIRST SEEN IN"
                    if mapped_field_name == "First Appearance" and infobox_data[mapped_field_name] is None:
                        infobox_data[mapped_field_name] = value_text
                    
                    # Handle "Family" and "Affiliation" to ensure multiple entries are separated by commas
                    elif mapped_field_name in ["Family", "Affiliation"]:
                        if infobox_data[mapped_field_name]:
                            infobox_data[mapped_field_name] += ", " + value_text
                        else:
                            infobox_data[mapped_field_name] = value_text
                    else:
                        infobox_data[mapped_field_name] = value_text

    return infobox_data

# Function to scrape character data and save connected URLs
def scrape_character_data(character_url):
    page = requests.get(character_url)
    soup = BeautifulSoup(page.content, 'html.parser')
    
    # Retrieve character name
    name = soup.find("h1", class_="page-header__title").text.strip()

    # Extract infobox data
    infobox_data = extract_infobox_data(soup)

    # Locate the main content section (using a div that typically holds character data)
    content_div = soup.find("div", class_="mw-parser-output")
    
    # Collect text content and links
    content_data = []
    page_links = []  # To store URLs linked within the character page

    # Collect all paragraphs and list items, storing text and links
    for element in content_div.find_all(['p', 'ul'], recursive=False):
        if "Fan Feed" in element.text:
            break  # Stop when reaching "Fan Feed"

        item_text = element.get_text(strip=True)
        content_data.append(item_text)

        # Extract and store all internal links in the current element
        for a in element.find_all('a', href=True):
            link_url = urljoin(character_url, a['href'])
            if "rickandmorty.fandom.com/wiki/" in link_url:
                page_links.append(link_url)

    # Structure data for saving
    character_data = {
        "name": name,
        "infobox": infobox_data,  # Add structured infobox data
        "content": "\n".join(content_data),  # Combine all text content into a single field
        "linked_pages": list(set(page_links))  # Store unique URLs to avoid duplicates
    }
    
    # Save each character's data as a JSON file in the specified folder
    filename = f"{folder_path}/{name.replace(' ', '_')}.json"
    with open(filename, "w", encoding="utf-8") as f:
        json.dump(character_data, f, indent=4)
    
    print(f"Saved {name} data to {filename}")
    return character_data

# Main function to iterate through all pages and scrape all characters
def scrape_all_characters(start_url):
    visited_links = set()  # To keep track of already-scraped characters
    current_page = start_url
    
    while current_page:
        print(f"Scraping page: {current_page}")
        character_links, next_page = get_character_links(current_page)
        
        # Scrape each character on the current page
        for link in character_links:
            if link in visited_links:  # Skip if already scraped
                print(f"Skipping already scraped character: {link}")
                continue
            
            try:
                scrape_character_data(link)  # Save data immediately for each character
                visited_links.add(link)  # Mark as visited
                time.sleep(1)  # Respectful delay
            except Exception as e:
                print(f"Failed to scrape {link}: {e}")
        
        # Move to the next page
        current_page = next_page

# Start URL for the character category
start_url = "https://rickandmorty.fandom.com/wiki/Category:Characters"
scrape_all_characters(start_url)
# Out:
# Scraping page: https://rickandmorty.fandom.com/wiki/Category:Characters
# Saved Abandoned Jerrys data to rickmorty_characters/Abandoned_Jerrys.json
# Saved Abrodolph Lincoler data to rickmorty_characters/Abrodolph_Lincoler.json
# Saved Adam data to rickmorty_characters/Adam.json
# Saved Adjudicator Rick data to rickmorty_characters/Adjudicator_Rick.json
# Saved Afro Rick data to rickmorty_characters/Afro_Rick.json
# Saved Agent Gribbles data to rickmorty_characters/Agent_Gribbles.json
# Saved Alan Rails data to rickmorty_characters/Alan_Rails.json
# Saved Albert Einstein data to rickmorty_characters/Albert_Einstein.json
# Saved Alexander data to rickmorty_characters/Alexander.json
# Saved Alien Googah data to rickmorty_characters/Alien_Googah.json
# Saved Alien Morty data to rickmorty_characters/Alien_Morty.json
# Saved Alien Rick data to rickmorty_characters/Alien_Rick.json
# Saved Alphabetrians data to rickmorty_characters/Alphabetrians.json
# Saved Alternate versions of characters data to rickmorty_characters/Alternate_versions_of_characters.json
# Saved Alyson Hannigan data to rickmorty_characters/Alyson_Hannigan.json
# Saved Amber Bunks data to rickmorty_characters/Amber_Bunks.json
# Saved Amfiddians data to rickmorty_characters/Amfiddians.json
# Saved Amish Cyborg data to rickmorty_characters/Amish_Cyborg.json
# Saved Annie data to rickmorty_characters/Annie.json
# Saved Annika data to rickmorty_characters/Annika.json
# Saved Antagonists data to rickmorty_characters/Antagonists.json
# Saved Antenna Morty data to rickmorty_characters/Antenna_Morty.json
# Saved Antenna Rick data to rickmorty_characters/Antenna_Rick.json
# Saved Ants in my Eyes Johnson data to rickmorty_characters/Ants_in_my_Eyes_Johnson.json
# Saved Ants in my Eyes Morty data to rickmorty_characters/Ants_in_my_Eyes_Morty.json
# Saved Aqua Morty data to rickmorty_characters/Aqua_Morty.json
# Saved Aqua Rick data to rickmorty_characters/Aqua_Rick.json
# Saved Arm Head Mutant Morty data to rickmorty_characters/Arm_Head_Mutant_Morty.json
# Saved Armagheadon data to rickmorty_characters/Armagheadon.json
# Saved Armothy data to rickmorty_characters/Armothy.json
# Saved Arthricia data to rickmorty_characters/Arthricia.json
# Saved Artist Morty data to rickmorty_characters/Artist_Morty.json
# Saved Attila Starwar data to rickmorty_characters/Attila_Starwar.json
# Saved Audit Observer data to rickmorty_characters/Audit_Observer.json
# Saved Baby Legs data to rickmorty_characters/Baby_Legs.json
# Saved Baby Wizard data to rickmorty_characters/Baby_Wizard.json
# Saved Balthromaw data to rickmorty_characters/Balthromaw.json
# Saved Bearded Lady data to rickmorty_characters/Bearded_Lady.json
# Saved Beebo data to rickmorty_characters/Beebo.json
# Saved Benjamin data to rickmorty_characters/Benjamin.json
# Saved Bepisians data to rickmorty_characters/Bepisians.json
# Saved Bertie data to rickmorty_characters/Bertie.json
# Saved Beta-Seven data to rickmorty_characters/Beta-Seven.json
# Saved Beth Sanchez (C-137) data to rickmorty_characters/Beth_Sanchez_(C-137).json
# Saved Beth Sanchez (C-500A) data to rickmorty_characters/Beth_Sanchez_(C-500A).json
# Saved Beth Sanchez (Simple Rick's Dimension) data to rickmorty_characters/Beth_Sanchez_(Simple_Rick's_Dimension).json
# Saved Beth Smith data to rickmorty_characters/Beth_Smith.json
# Saved Beth Smith (304-X) data to rickmorty_characters/Beth_Smith_(304-X).json
# Saved Beth Smith (5126) data to rickmorty_characters/Beth_Smith_(5126).json
# Saved Beth Smith (C-132) data to rickmorty_characters/Beth_Smith_(C-132).json
# Saved Beth Smith (C-290) data to rickmorty_characters/Beth_Smith_(C-290).json
# Saved Beth Smith (Evil Rick's Target Dimension) data to rickmorty_characters/Beth_Smith_(Evil_Rick's_Target_Dimension).json
# Saved Beth Smith (Parmesan Dimension) data to rickmorty_characters/Beth_Smith_(Parmesan_Dimension).json
# Saved Beth Smith Prime data to rickmorty_characters/Beth_Smith_Prime.json
# Saved Beth's Mytholog data to rickmorty_characters/Beth's_Mytholog.json
# Saved Big Boobed Waitress data to rickmorty_characters/Big_Boobed_Waitress.json
# Saved Big Doug data to rickmorty_characters/Big_Doug.json
# Saved Big Fat Rick data to rickmorty_characters/Big_Fat_Rick.json
# Saved Big Morty data to rickmorty_characters/Big_Morty.json
# Saved Big Morty's Bodyguard Mortys data to rickmorty_characters/Big_Morty's_Bodyguard_Mortys.json
# Saved Big-Head Morty data to rickmorty_characters/Big-Head_Morty.json
# Saved Bigfoot data to rickmorty_characters/Bigfoot.json
# Saved Bill (Dog) data to rickmorty_characters/Bill_(Dog).json
# Saved Birddaughter data to rickmorty_characters/Birddaughter.json
# Saved Birdperson data to rickmorty_characters/Birdperson.json
# Saved Blamphs data to rickmorty_characters/Blamphs.json
# Saved Blazen data to rickmorty_characters/Blazen.json
# Saved Blim Blam data to rickmorty_characters/Blim_Blam.json
# Saved Blue Footprint Guy data to rickmorty_characters/Blue_Footprint_Guy.json
# Saved Blue Shirt Morty data to rickmorty_characters/Blue_Shirt_Morty.json
# Saved Bobby Moynihan data to rickmorty_characters/Bobby_Moynihan.json
# Saved Boobloosians data to rickmorty_characters/Boobloosians.json
# Saved Bootleg Portal Chemist Rick data to rickmorty_characters/Bootleg_Portal_Chemist_Rick.json
# Saved Borpocians data to rickmorty_characters/Borpocians.json
# Saved Bova data to rickmorty_characters/Bova.json
# Saved Brad data to rickmorty_characters/Brad.json
# Saved Brad Anderson data to rickmorty_characters/Brad_Anderson.json
# Saved Brosephamons data to rickmorty_characters/Brosephamons.json
# Saved Bruce Chutback data to rickmorty_characters/Bruce_Chutback.json
# Saved Bullies data to rickmorty_characters/Bullies.json
# Saved Butter Robot (Fortnite) data to rickmorty_characters/Butter_Robot_(Fortnite).json
# Saved Buttmouth data to rickmorty_characters/Buttmouth.json
# Saved By gender data to rickmorty_characters/By_gender.json
# Saved By status data to rickmorty_characters/By_status.json
# Saved Calypso data to rickmorty_characters/Calypso.json
# Saved Canklanker Thom data to rickmorty_characters/Canklanker_Thom.json
# Saved Catogami data to rickmorty_characters/Catogami.json
# Saved Cecelia data to rickmorty_characters/Cecelia.json
# Saved Centaur data to rickmorty_characters/Centaur.json
# Saved Characters by species data to rickmorty_characters/Characters_by_species.json
# Saved Characters from Dimension C-137 data to rickmorty_characters/Characters_from_Dimension_C-137.json
# Saved Characters voiced by Chris Parnell data to rickmorty_characters/Characters_voiced_by_Chris_Parnell.json
# Saved Characters Voiced by Dan Harmon data to rickmorty_characters/Characters_Voiced_by_Dan_Harmon.json
# Saved Characters voiced by Justin Roiland data to rickmorty_characters/Characters_voiced_by_Justin_Roiland.json
# Saved Characters Voiced by Maurice LaMarche data to rickmorty_characters/Characters_Voiced_by_Maurice_LaMarche.json
# Saved Characters voiced by Ryan Ridley data to rickmorty_characters/Characters_voiced_by_Ryan_Ridley.json
# Saved Characters Voiced by Tom Kenny data to rickmorty_characters/Characters_Voiced_by_Tom_Kenny.json
# Saved Chris data to rickmorty_characters/Chris.json
# Saved Chris (The Ricks Must Be Crazy) data to rickmorty_characters/Chris_(The_Ricks_Must_Be_Crazy).json
# Saved Chud King data to rickmorty_characters/Chud_King.json
# Saved Churry data to rickmorty_characters/Churry.json
# Saved Chuxly data to rickmorty_characters/Chuxly.json
# Saved Clone 5617B data to rickmorty_characters/Clone_5617B.json
# Saved Coach Feratu data to rickmorty_characters/Coach_Feratu.json
# Saved Colossus data to rickmorty_characters/Colossus.json
# Saved Comedian data to rickmorty_characters/Comedian.json
# Saved Comic Characters data to rickmorty_characters/Comic_Characters.json
# Saved Commander Rick data to rickmorty_characters/Commander_Rick.json
# Saved Concerto data to rickmorty_characters/Concerto.json
# Saved Connie TinuityError data to rickmorty_characters/Connie_TinuityError.json
# Saved Conroy data to rickmorty_characters/Conroy.json
# Saved Cookie Magneto data to rickmorty_characters/Cookie_Magneto.json
# Saved Cool Rick data to rickmorty_characters/Cool_Rick.json
# Saved Coop data to rickmorty_characters/Coop.json
# Saved Cornvelious Daniel data to rickmorty_characters/Cornvelious_Daniel.json
# Saved Council of Ricks data to rickmorty_characters/Council_of_Ricks.json
# Saved Courier Flap data to rickmorty_characters/Courier_Flap.json
# Saved Cousin Nicky data to rickmorty_characters/Cousin_Nicky.json
# Saved Crazy Cat Rick data to rickmorty_characters/Crazy_Cat_Rick.json
# Saved Crocubot data to rickmorty_characters/Crocubot.json
# Saved Cromulons data to rickmorty_characters/Cromulons.json
# Saved Cronenberg Morty data to rickmorty_characters/Cronenberg_Morty.json
# Saved Cronenberg Rick data to rickmorty_characters/Cronenberg_Rick.json
# Saved Crop Top Morty data to rickmorty_characters/Crop_Top_Morty.json
# Saved Crowscare data to rickmorty_characters/Crowscare.json
# Saved Crustolomons data to rickmorty_characters/Crustolomons.json
# Saved Crystallized Morty data to rickmorty_characters/Crystallized_Morty.json
# Saved Cult Leader Morty data to rickmorty_characters/Cult_Leader_Morty.json
# Saved Curly-haired Rick data to rickmorty_characters/Curly-haired_Rick.json
# Saved Cyclops Morty data to rickmorty_characters/Cyclops_Morty.json
# Saved Cyclops Rick data to rickmorty_characters/Cyclops_Rick.json
# Saved Cynthia data to rickmorty_characters/Cynthia.json
# Saved Cynthia (Rixty Minutes) data to rickmorty_characters/Cynthia_(Rixty_Minutes).json
# Saved Dale data to rickmorty_characters/Dale.json
# Saved Dale's Son data to rickmorty_characters/Dale's_Son.json
# Saved Dangelians data to rickmorty_characters/Dangelians.json
# Saved Daphne data to rickmorty_characters/Daphne.json
# Saved Daron Jefferson data to rickmorty_characters/Daron_Jefferson.json
# Saved Darth Poopybutthole data to rickmorty_characters/Darth_Poopybutthole.json
# Saved Dave data to rickmorty_characters/Dave.json
# Saved David Letterman data to rickmorty_characters/David_Letterman.json
# Saved David Prime data to rickmorty_characters/David_Prime.json
# Saved Davin data to rickmorty_characters/Davin.json
# Saved Da’hou Ungherstahnk data to rickmorty_characters/Da’hou_Ungherstahnk.json
# Saved Dead in all dimensions data to rickmorty_characters/Dead_in_all_dimensions.json
# Saved Deceased Characters data to rickmorty_characters/Deceased_Characters.json
# Saved Decimal Point data to rickmorty_characters/Decimal_Point.json
# Saved Defiance Doctor data to rickmorty_characters/Defiance_Doctor.json
# Saved Delta data to rickmorty_characters/Delta.json
# Saved Diablo Verde data to rickmorty_characters/Diablo_Verde.json
# Saved Diane Sanchez data to rickmorty_characters/Diane_Sanchez.json
# Saved Diesel Weasel data to rickmorty_characters/Diesel_Weasel.json
# Saved Dimension 5126 Residents data to rickmorty_characters/Dimension_5126_Residents.json
# Saved Dimensional travel family data to rickmorty_characters/Dimensional_travel_family.json
# Saved Dipper and Mabel Mortys data to rickmorty_characters/Dipper_and_Mabel_Mortys.json
# Saved Diseases data to rickmorty_characters/Diseases.json
# Saved Disheveled Rick data to rickmorty_characters/Disheveled_Rick.json
# Saved Doctor Buckles data to rickmorty_characters/Doctor_Buckles.json
# Saved Donna Guterman data to rickmorty_characters/Donna_Guterman.json
# Saved Doofus Rick data to rickmorty_characters/Doofus_Rick.json
# Saved Doom-Nomitron data to rickmorty_characters/Doom-Nomitron.json
# Saved Dougie data to rickmorty_characters/Dougie.json
# Saved Dr. Glip-Glop data to rickmorty_characters/Dr._Glip-Glop.json
# Saved Dr. Schmidt data to rickmorty_characters/Dr._Schmidt.json
# Saved Dr. Wong data to rickmorty_characters/Dr._Wong.json
# Saved Dr. Xenon Bloom data to rickmorty_characters/Dr._Xenon_Bloom.json
# Saved Drippy Boy data to rickmorty_characters/Drippy_Boy.json
# Saved Duck with Muscles data to rickmorty_characters/Duck_with_Muscles.json
# Saved Dwayne data to rickmorty_characters/Dwayne.json
# Saved Earl Bunks data to rickmorty_characters/Earl_Bunks.json
# Saved Earl of Earth data to rickmorty_characters/Earl_of_Earth.json
# Saved Eddie data to rickmorty_characters/Eddie.json
# Saved Edna Bunks data to rickmorty_characters/Edna_Bunks.json
# Saved Eli data to rickmorty_characters/Eli.json
# Saved Eli's Girlfriend data to rickmorty_characters/Eli's_Girlfriend.json
# Saved Elle data to rickmorty_characters/Elle.json
# Saved Emperor Dread Nought data to rickmorty_characters/Emperor_Dread_Nought.json
# Saved Eric Stoltz Mask Morty data to rickmorty_characters/Eric_Stoltz_Mask_Morty.json
# Saved Ethan data to rickmorty_characters/Ethan.json
# Saved Evil Beth Clone data to rickmorty_characters/Evil_Beth_Clone.json
# Saved Evil Jerry Clone data to rickmorty_characters/Evil_Jerry_Clone.json
# Saved Evil Morty data to rickmorty_characters/Evil_Morty.json
# Failed to scrape https://rickandmorty.fandom.com/wiki/Evil_Morty/Theories: [Errno 2] No such file or directory: 'rickmorty_characters/Evil_Morty/Theories.json'
# Saved Evil Rick data to rickmorty_characters/Evil_Rick.json
# Saved Evil Summer Clone data to rickmorty_characters/Evil_Summer_Clone.json
# Saved Eyehole Man data to rickmorty_characters/Eyehole_Man.json
# Saved Farmer Rick data to rickmorty_characters/Farmer_Rick.json
# Saved Farmer Rick's Dog data to rickmorty_characters/Farmer_Rick's_Dog.json
# Saved Fart data to rickmorty_characters/Fart.json
# Saved Fascist Morty data to rickmorty_characters/Fascist_Morty.json
# Saved Fast Aging Alien data to rickmorty_characters/Fast_Aging_Alien.json
# Saved Father Bob data to rickmorty_characters/Father_Bob.json
# Saved Fear Hole Demon data to rickmorty_characters/Fear_Hole_Demon.json
# Saved Fictional Characters data to rickmorty_characters/Fictional_Characters.json
# Saved Flansians data to rickmorty_characters/Flansians.json
# Saved Flash Back data to rickmorty_characters/Flash_Back.json
# Saved Fleeb data to rickmorty_characters/Fleeb.json
# Saved Fleeblebox IV data to rickmorty_characters/Fleeblebox_IV.json
# Saved Flex Xando data to rickmorty_characters/Flex_Xando.json
# Saved Florflok data to rickmorty_characters/Florflok.json
# Scraping page: https://rickandmorty.fandom.com/wiki/Category:Characters?from=Frank+Palicky
# Saved Frank Palicky data to rickmorty_characters/Frank_Palicky.json
# Saved Frankenstein's Monster data to rickmorty_characters/Frankenstein's_Monster.json
# Saved Franklin Roosevelt data to rickmorty_characters/Franklin_Roosevelt.json
# Saved Fred Bunks data to rickmorty_characters/Fred_Bunks.json
# Saved Fulgora data to rickmorty_characters/Fulgora.json
# Saved Fungo data to rickmorty_characters/Fungo.json
# Saved Gaia data to rickmorty_characters/Gaia.json
# Saved Galactic Federation President data to rickmorty_characters/Galactic_Federation_President.json
# Saved Gar Gloonch data to rickmorty_characters/Gar_Gloonch.json
# Saved Gar's Mytholog data to rickmorty_characters/Gar's_Mytholog.json
# Saved Garblovians data to rickmorty_characters/Garblovians.json
# Saved Garmanarnar data to rickmorty_characters/Garmanarnar.json
# Saved Garment District Rick data to rickmorty_characters/Garment_District_Rick.json
# Saved Gazorpazorpfield (Character) data to rickmorty_characters/Gazorpazorpfield_(Character).json
# Saved Gazorpians data to rickmorty_characters/Gazorpians.json
# Saved Geardude data to rickmorty_characters/Geardude.json
# Saved Gene data to rickmorty_characters/Gene.json
# Saved General Nathan data to rickmorty_characters/General_Nathan.json
# Saved General Store Owner data to rickmorty_characters/General_Store_Owner.json
# Saved Genital Washer data to rickmorty_characters/Genital_Washer.json
# Saved Ghost in a Jar data to rickmorty_characters/Ghost_in_a_Jar.json
# Saved Gibble Snake data to rickmorty_characters/Gibble_Snake.json
# Saved Glar data to rickmorty_characters/Glar.json
# Saved Glarb data to rickmorty_characters/Glarb.json
# Saved Glasses Morty data to rickmorty_characters/Glasses_Morty.json
# Saved Glaxo Slimslom data to rickmorty_characters/Glaxo_Slimslom.json
# Saved Glenn data to rickmorty_characters/Glenn.json
# Saved Glenn (Rixty Minutes) data to rickmorty_characters/Glenn_(Rixty_Minutes).json
# Saved Glootie data to rickmorty_characters/Glootie.json
# Saved GlorpDieBlorp data to rickmorty_characters/GlorpDieBlorp.json
# Saved Gobo data to rickmorty_characters/Gobo.json
# Saved Goddess Beth data to rickmorty_characters/Goddess_Beth.json
# Saved Gods data to rickmorty_characters/Gods.json
# Saved Goomby data to rickmorty_characters/Goomby.json
# Saved Gordon Lunas data to rickmorty_characters/Gordon_Lunas.json
# Saved Gorpathian Dermaks data to rickmorty_characters/Gorpathian_Dermaks.json
# Saved Grace data to rickmorty_characters/Grace.json
# Saved Grace Smith data to rickmorty_characters/Grace_Smith.json
# Saved Green Alien data to rickmorty_characters/Green_Alien.json
# Saved Green Alien's son data to rickmorty_characters/Green_Alien's_son.json
# Saved Green Alien's wife data to rickmorty_characters/Green_Alien's_wife.json
# Saved Greg data to rickmorty_characters/Greg.json
# Saved Gromflomite guard 4 data to rickmorty_characters/Gromflomite_guard_4.json
# Saved Gromflomites data to rickmorty_characters/Gromflomites.json
# Saved Gwendolyn data to rickmorty_characters/Gwendolyn.json
# Saved Hambrosians data to rickmorty_characters/Hambrosians.json
# Saved Hammerhead Morty data to rickmorty_characters/Hammerhead_Morty.json
# Saved Hammerhead Morty (Fortnite) data to rickmorty_characters/Hammerhead_Morty_(Fortnite).json
# Saved Hamsters In Butts data to rickmorty_characters/Hamsters_In_Butts.json
# Saved Hamurai data to rickmorty_characters/Hamurai.json
# Saved Harold data to rickmorty_characters/Harold.json
# Saved Harold The Garbage Goober data to rickmorty_characters/Harold_The_Garbage_Goober.json
# Saved Healthy Rick data to rickmorty_characters/Healthy_Rick.json
# Saved Heistotron data to rickmorty_characters/Heistotron.json
# Saved Hemorrhage data to rickmorty_characters/Hemorrhage.json
# Saved Hephaestus data to rickmorty_characters/Hephaestus.json
# Saved Heroin Keith data to rickmorty_characters/Heroin_Keith.json
# Saved Higher-Dimensional Beings data to rickmorty_characters/Higher-Dimensional_Beings.json
# Saved Hole in the Wall Where the Men Can See it All data to rickmorty_characters/Hole_in_the_Wall_Where_the_Men_Can_See_it_All.json
# Saved Holly Hooks data to rickmorty_characters/Holly_Hooks.json
# Saved Hologram Rick data to rickmorty_characters/Hologram_Rick.json
# Saved Hologram Rick (Edge of Tomorty: Rick Die Repeat) data to rickmorty_characters/Hologram_Rick_(Edge_of_Tomorty:_Rick_Die_Repeat).json
# Saved Hookah Alien data to rickmorty_characters/Hookah_Alien.json
# Saved Hoovy data to rickmorty_characters/Hoovy.json
# Saved Hothead Rick data to rickmorty_characters/Hothead_Rick.json
# Saved Hugh Jackman data to rickmorty_characters/Hugh_Jackman.json
# Saved Hunter data to rickmorty_characters/Hunter.json
# Saved Hunter's Father data to rickmorty_characters/Hunter's_Father.json
# Saved Hydrogen-F data to rickmorty_characters/Hydrogen-F.json
# Saved Ice Cube data to rickmorty_characters/Ice_Cube.json
# Saved Ideal Jerry data to rickmorty_characters/Ideal_Jerry.json
# Saved Imaginary Characters data to rickmorty_characters/Imaginary_Characters.json
# Saved Indiana Jones Rick data to rickmorty_characters/Indiana_Jones_Rick.json
# Saved Infinity data to rickmorty_characters/Infinity.json
# Saved Insurance Rick data to rickmorty_characters/Insurance_Rick.json
# Saved Interdimensional Cable Characters data to rickmorty_characters/Interdimensional_Cable_Characters.json
# Saved Investigator Rick data to rickmorty_characters/Investigator_Rick.json
# Saved Invisi-troopers data to rickmorty_characters/Invisi-troopers.json
# Saved Izzy data to rickmorty_characters/Izzy.json
# Saved Jackie data to rickmorty_characters/Jackie.json
# Saved Jacob Philip data to rickmorty_characters/Jacob_Philip.json
# Saved Jacqueline data to rickmorty_characters/Jacqueline.json
# Saved Jaguar data to rickmorty_characters/Jaguar.json
# Saved James Bond Rick data to rickmorty_characters/James_Bond_Rick.json
# Saved Jamey data to rickmorty_characters/Jamey.json
# Saved Jan data to rickmorty_characters/Jan.json
# Saved Jan-Michael Vincent data to rickmorty_characters/Jan-Michael_Vincent.json
# Saved Japheth data to rickmorty_characters/Japheth.json
# Saved Jarshog Mollar data to rickmorty_characters/Jarshog_Mollar.json
# Saved Jeff data to rickmorty_characters/Jeff.json
# Saved Jerricky data to rickmorty_characters/Jerricky.json
# Saved Jerry Clone Head data to rickmorty_characters/Jerry_Clone_Head.json
# Saved Jerry Jr. data to rickmorty_characters/Jerry_Jr..json
# Saved Jerry Smith (304-X) data to rickmorty_characters/Jerry_Smith_(304-X).json
# Saved Jerry Smith (C-131) data to rickmorty_characters/Jerry_Smith_(C-131).json
# Saved Jerry Smith (C-500A) data to rickmorty_characters/Jerry_Smith_(C-500A).json
# Saved Jerry Smith (Evil Rick's Target Dimension) data to rickmorty_characters/Jerry_Smith_(Evil_Rick's_Target_Dimension).json
# Saved Jerry Smith (Parmesan Dimension) data to rickmorty_characters/Jerry_Smith_(Parmesan_Dimension).json
# Saved Jerry Smith Prime data to rickmorty_characters/Jerry_Smith_Prime.json
# Saved Jerry's Mytholog data to rickmorty_characters/Jerry's_Mytholog.json
# Saved Jerry's school friend data to rickmorty_characters/Jerry's_school_friend.json
# Saved Jerry Rick data to rickmorty_characters/Jerry_Rick.json
# Saved Jessica (C-131) data to rickmorty_characters/Jessica_(C-131).json
# Saved Jessica (Parmesan Dimension) data to rickmorty_characters/Jessica_(Parmesan_Dimension).json
# Saved Jessica Prime data to rickmorty_characters/Jessica_Prime.json
# Saved Jessica's Grandma data to rickmorty_characters/Jessica's_Grandma.json
# Saved Jesus Christ data to rickmorty_characters/Jesus_Christ.json
# Saved Jew data to rickmorty_characters/Jew.json
# Saved Jimmy data to rickmorty_characters/Jimmy.json
# Saved Jodie data to rickmorty_characters/Jodie.json
# Saved John McLane Rick data to rickmorty_characters/John_McLane_Rick.json
# Saved Johnny Depp data to rickmorty_characters/Johnny_Depp.json
# Saved Jon data to rickmorty_characters/Jon.json
# Saved Joseph Campbell data to rickmorty_characters/Joseph_Campbell.json
# Saved Joseph Lipnip data to rickmorty_characters/Joseph_Lipnip.json
# Saved Josiah data to rickmorty_characters/Josiah.json
# Saved Joyce Smith data to rickmorty_characters/Joyce_Smith.json
# Saved Judge Observer data to rickmorty_characters/Judge_Observer.json
# Saved Juggling Rick data to rickmorty_characters/Juggling_Rick.json
# Saved Karen Entity data to rickmorty_characters/Karen_Entity.json
# Saved Katarina data to rickmorty_characters/Katarina.json
# Saved Katherine Heffelfinger data to rickmorty_characters/Katherine_Heffelfinger.json
# Saved Kathy Ireland data to rickmorty_characters/Kathy_Ireland.json
# Saved Kelsey Shawsen data to rickmorty_characters/Kelsey_Shawsen.json
# Saved Kendra data to rickmorty_characters/Kendra.json
# Saved Kevin data to rickmorty_characters/Kevin.json
# Saved Khlorgg data to rickmorty_characters/Khlorgg.json
# Saved Kiara data to rickmorty_characters/Kiara.json
# Saved King Flippy Nips data to rickmorty_characters/King_Flippy_Nips.json
# Saved King Stephen data to rickmorty_characters/King_Stephen.json
# Saved Kl’iiik Mijupsrit data to rickmorty_characters/Kl’iiik_Mijupsrit.json
# Saved Korlunxes data to rickmorty_characters/Korlunxes.json
# Saved Kozbians data to rickmorty_characters/Kozbians.json
# Saved Kristen Stewart data to rickmorty_characters/Kristen_Stewart.json
# Saved Krombopulos Michael data to rickmorty_characters/Krombopulos_Michael.json
# Saved Kyle data to rickmorty_characters/Kyle.json
# Saved Lady Katana data to rickmorty_characters/Lady_Katana.json
# Saved Larry data to rickmorty_characters/Larry.json
# Saved Larvaalians data to rickmorty_characters/Larvaalians.json
# Saved Lawrence Maps data to rickmorty_characters/Lawrence_Maps.json
# Saved Lawyer Morty data to rickmorty_characters/Lawyer_Morty.json
# Saved Lawyer Observer data to rickmorty_characters/Lawyer_Observer.json
# Saved Leonard Smith data to rickmorty_characters/Leonard_Smith.json
# Saved Leonard's Brother data to rickmorty_characters/Leonard's_Brother.json
# Saved LGBT Characters data to rickmorty_characters/LGBT_Characters.json
# Saved Lighthouse Keeper data to rickmorty_characters/Lighthouse_Keeper.json
# Saved Lil B data to rickmorty_characters/Lil_B.json
# Saved Lipnip Family data to rickmorty_characters/Lipnip_Family.json
# Saved Lisa data to rickmorty_characters/Lisa.json
# Saved Little Dipper data to rickmorty_characters/Little_Dipper.json
# Saved Little Ricky Wrap-it-up data to rickmorty_characters/Little_Ricky_Wrap-it-up.json
# Saved Lizard Morty data to rickmorty_characters/Lizard_Morty.json
# Saved Lizard Rick data to rickmorty_characters/Lizard_Rick.json
# Saved Loggins data to rickmorty_characters/Loggins.json
# Saved Logic data to rickmorty_characters/Logic.json
# Saved Long Sleeved Morty data to rickmorty_characters/Long_Sleeved_Morty.json
# Saved Lord Henderfinger data to rickmorty_characters/Lord_Henderfinger.json
# Saved Love Interests data to rickmorty_characters/Love_Interests.json
# Saved Lucius Needful data to rickmorty_characters/Lucius_Needful.json
# Saved Lucy data to rickmorty_characters/Lucy.json
# Saved Madame President data to rickmorty_characters/Madame_President.json
# Saved Maggie data to rickmorty_characters/Maggie.json
# Saved Magma-Q data to rickmorty_characters/Magma-Q.json
# Saved Magma-T data to rickmorty_characters/Magma-T.json
# Saved Magnesium-J data to rickmorty_characters/Magnesium-J.json
# Saved Man Painted Silver Who Makes Robot Noises data to rickmorty_characters/Man_Painted_Silver_Who_Makes_Robot_Noises.json
# Saved Mar-Sha data to rickmorty_characters/Mar-Sha.json
# Saved Marta data to rickmorty_characters/Marta.json
# Saved Masy Kallerax data to rickmorty_characters/Masy_Kallerax.json
# Saved Maximums Rickimus data to rickmorty_characters/Maximums_Rickimus.json
# Saved MC Haps data to rickmorty_characters/MC_Haps.json
# Saved McGlaargle data to rickmorty_characters/McGlaargle.json
# Saved Mecha Morty (Fortnite) data to rickmorty_characters/Mecha_Morty_(Fortnite).json
# Saved Mechanical Morty data to rickmorty_characters/Mechanical_Morty.json
# Saved Mechanical Rick data to rickmorty_characters/Mechanical_Rick.json
# Saved Mechanical Summer data to rickmorty_characters/Mechanical_Summer.json
# Saved Memory Parasites data to rickmorty_characters/Memory_Parasites.json
# Saved Memory Rick data to rickmorty_characters/Memory_Rick.json
# Saved Michael (That's Amorte) data to rickmorty_characters/Michael_(That's_Amorte).json
# Saved Michael (The ABC's of Beth) data to rickmorty_characters/Michael_(The_ABC's_of_Beth).json
# Saved Michael Denny and the Denny Singers data to rickmorty_characters/Michael_Denny_and_the_Denny_Singers.json
# Saved Michael Jenkins data to rickmorty_characters/Michael_Jenkins.json
# Saved Michael McLick data to rickmorty_characters/Michael_McLick.json
# Saved Michael Thompson data to rickmorty_characters/Michael_Thompson.json
# Saved Miggs data to rickmorty_characters/Miggs.json
# Saved Miles Knightly data to rickmorty_characters/Miles_Knightly.json
# Saved Million Ants data to rickmorty_characters/Million_Ants.json
# Saved Miss Lead data to rickmorty_characters/Miss_Lead.json
# Saved Mitch data to rickmorty_characters/Mitch.json
# Saved Morty Jr. data to rickmorty_characters/Morty_Jr..json
# Saved Morty Rick data to rickmorty_characters/Morty_Rick.json
# Saved Morty Smith data to rickmorty_characters/Morty_Smith.json
# Saved Morty Smith (304-X) data to rickmorty_characters/Morty_Smith_(304-X).json
# Saved Morty Smith (C-131) data to rickmorty_characters/Morty_Smith_(C-131).json
# Saved Morty Smith (C-132) data to rickmorty_characters/Morty_Smith_(C-132).json
# Saved Morty Smith (C-290) data to rickmorty_characters/Morty_Smith_(C-290).json
# Saved Morty Smith (Evil Rick's Target Dimension) data to rickmorty_characters/Morty_Smith_(Evil_Rick's_Target_Dimension).json
# Saved Morty Smith (K-22) data to rickmorty_characters/Morty_Smith_(K-22).json
# Saved Morty Smith (Parmesan Dimension) data to rickmorty_characters/Morty_Smith_(Parmesan_Dimension).json
# Saved Morty's Girlfriend data to rickmorty_characters/Morty's_Girlfriend.json
# Scraping page: https://rickandmorty.fandom.com/wiki/Category:Characters?from=Mortytown+Locos
# Saved Mortytown Locos data to rickmorty_characters/Mortytown_Locos.json
# Saved Mr. Always Wants To Be Hunted data to rickmorty_characters/Mr._Always_Wants_To_Be_Hunted.json
# Saved Mr. Beauregard data to rickmorty_characters/Mr._Beauregard.json
# Saved Mr. Benson data to rickmorty_characters/Mr._Benson.json
# Saved Mr. Booby Buyer data to rickmorty_characters/Mr._Booby_Buyer.json
# Saved Mr. Calypso data to rickmorty_characters/Mr._Calypso.json
# Saved Mr. Frundles data to rickmorty_characters/Mr._Frundles.json
# Saved Mr. Goldenfold data to rickmorty_characters/Mr._Goldenfold.json
# Saved Mr. Goldenfold (Wasp Universe) data to rickmorty_characters/Mr._Goldenfold_(Wasp_Universe).json
# Saved Mr. Goldenfold's Larvae data to rickmorty_characters/Mr._Goldenfold's_Larvae.json
# Saved Mr. Goldmanbachmajorian data to rickmorty_characters/Mr._Goldmanbachmajorian.json
# Saved Mr. Marklovitz data to rickmorty_characters/Mr._Marklovitz.json
# Saved Mr. Meeseeks data to rickmorty_characters/Mr._Meeseeks.json
# Saved Mr. Meeseeks (Fortnite) data to rickmorty_characters/Mr._Meeseeks_(Fortnite).json
# Saved Mr. Meeseeks (Kirkland) data to rickmorty_characters/Mr._Meeseeks_(Kirkland).json
# Saved Mr. Nimbus data to rickmorty_characters/Mr._Nimbus.json
# Saved Mr. Poopybutthole data to rickmorty_characters/Mr._Poopybutthole.json
# Saved Mr. Poopybutthole's Cat data to rickmorty_characters/Mr._Poopybutthole's_Cat.json
# Saved Mr. Poopybutthole's Dog data to rickmorty_characters/Mr._Poopybutthole's_Dog.json
# Saved Mr. Sneezy data to rickmorty_characters/Mr._Sneezy.json
# Saved Mr. Stringbean data to rickmorty_characters/Mr._Stringbean.json
# Saved Mr. Twist data to rickmorty_characters/Mr._Twist.json
# Saved Mr. Youseeks data to rickmorty_characters/Mr._Youseeks.json
# Saved Mrs. Lipnip data to rickmorty_characters/Mrs._Lipnip.json
# Saved Mrs. Pancakes data to rickmorty_characters/Mrs._Pancakes.json
# Saved Mrs. Poopybutthole data to rickmorty_characters/Mrs._Poopybutthole.json
# Saved Mrs. Refrigerator data to rickmorty_characters/Mrs._Refrigerator.json
# Saved Mrs. Sullivan data to rickmorty_characters/Mrs._Sullivan.json
# Saved Mysterious Rick data to rickmorty_characters/Mysterious_Rick.json
# Saved Nana data to rickmorty_characters/Nana.json
# Saved Nancy data to rickmorty_characters/Nancy.json
# Saved Naruto Smith data to rickmorty_characters/Naruto_Smith.json
# Saved Neeeews Reporter data to rickmorty_characters/Neeeews_Reporter.json
# Saved Nerd Rick data to rickmorty_characters/Nerd_Rick.json
# Saved Nice Rick data to rickmorty_characters/Nice_Rick.json
# Saved Nick data to rickmorty_characters/Nick.json
# Saved Night Jerry data to rickmorty_characters/Night_Jerry.json
# Saved Nippalians data to rickmorty_characters/Nippalians.json
# Saved No-Outline Morty data to rickmorty_characters/No-Outline_Morty.json
# Saved Noob-Noob data to rickmorty_characters/Noob-Noob.json
# Saved Numbericons data to rickmorty_characters/Numbericons.json
# Saved Octopus Man data to rickmorty_characters/Octopus_Man.json
# Saved Old Reptile data to rickmorty_characters/Old_Reptile.json
# Saved One-Time Characters data to rickmorty_characters/One-Time_Characters.json
# Saved Pants on Head Mutant Morty data to rickmorty_characters/Pants_on_Head_Mutant_Morty.json
# Saved Parents data to rickmorty_characters/Parents.json
# Saved Pat Guterman data to rickmorty_characters/Pat_Guterman.json
# Saved Paul Fleishman data to rickmorty_characters/Paul_Fleishman.json
# Saved Pawnshop Clerk data to rickmorty_characters/Pawnshop_Clerk.json
# Saved Pencilvester data to rickmorty_characters/Pencilvester.json
# Saved Phillip Jacobs data to rickmorty_characters/Phillip_Jacobs.json
# Saved Photography Cyborgs data to rickmorty_characters/Photography_Cyborgs.json
# Saved Photography Raptor data to rickmorty_characters/Photography_Raptor.json
# Saved Pichael Thompson data to rickmorty_characters/Pichael_Thompson.json
# Saved Pickle Rick (character) data to rickmorty_characters/Pickle_Rick_(character).json
# Saved Pickle Rick (Fortnite) data to rickmorty_characters/Pickle_Rick_(Fortnite).json
# Saved Pickles the Drummer data to rickmorty_characters/Pickles_the_Drummer.json
# Saved Piece of Toast data to rickmorty_characters/Piece_of_Toast.json
# Saved Pink Sentient Switchblade data to rickmorty_characters/Pink_Sentient_Switchblade.json
# Saved Planetina data to rickmorty_characters/Planetina.json
# Saved Plumber Rick data to rickmorty_characters/Plumber_Rick.json
# Saved Plutonian data to rickmorty_characters/Plutonian.json
# Saved Political Figures data to rickmorty_characters/Political_Figures.json
# Saved Poncho data to rickmorty_characters/Poncho.json
# Saved Poop Jesus data to rickmorty_characters/Poop_Jesus.json
# Saved Poopy Jr. data to rickmorty_characters/Poopy_Jr..json
# Saved Poopybutthole Family data to rickmorty_characters/Poopybutthole_Family.json
# Saved Pop-Pop data to rickmorty_characters/Pop-Pop.json
# Saved Poñeta data to rickmorty_characters/Poñeta.json
# Saved President Curtis data to rickmorty_characters/President_Curtis.json
# Saved President Leland data to rickmorty_characters/President_Leland.json
# Saved Presidentress of the Mega Gargantuans data to rickmorty_characters/Presidentress_of_the_Mega_Gargantuans.json
# Saved Previous Leon data to rickmorty_characters/Previous_Leon.json
# Saved Priest Witherspoon data to rickmorty_characters/Priest_Witherspoon.json
# Saved Prince Nebulon data to rickmorty_characters/Prince_Nebulon.json
# Saved Principal Vagina data to rickmorty_characters/Principal_Vagina.json
# Saved Pripudlians data to rickmorty_characters/Pripudlians.json
# Saved Professor Shabooboo data to rickmorty_characters/Professor_Shabooboo.json
# Saved Professor Tock data to rickmorty_characters/Professor_Tock.json
# Saved Prosecutor Observer data to rickmorty_characters/Prosecutor_Observer.json
# Saved Protago Nick data to rickmorty_characters/Protago_Nick.json
# Saved Protagonists data to rickmorty_characters/Protagonists.json
# Saved Purge Planet Ruler data to rickmorty_characters/Purge_Planet_Ruler.json
# Saved Purpose Robot data to rickmorty_characters/Purpose_Robot.json
# Saved Pussifer data to rickmorty_characters/Pussifer.json
# Saved Quantum Rick data to rickmorty_characters/Quantum_Rick.json
# Saved Queen Summer data to rickmorty_characters/Queen_Summer.json
# Saved Rainbow Suspenders Guy data to rickmorty_characters/Rainbow_Suspenders_Guy.json
# Saved Randy Dicknose data to rickmorty_characters/Randy_Dicknose.json
# Saved Real Fake Doors Salesman data to rickmorty_characters/Real_Fake_Doors_Salesman.json
# Saved Real People data to rickmorty_characters/Real_People.json
# Saved Rebel Doctor data to rickmorty_characters/Rebel_Doctor.json
# Saved Rebel Rick data to rickmorty_characters/Rebel_Rick.json
# Saved Recurring Characters data to rickmorty_characters/Recurring_Characters.json
# Saved Redgren Grumbholdt data to rickmorty_characters/Redgren_Grumbholdt.json
# Saved Reggie data to rickmorty_characters/Reggie.json
# Saved Regional Manager Rick data to rickmorty_characters/Regional_Manager_Rick.json
# Saved Regular Legs data to rickmorty_characters/Regular_Legs.json
# Saved Religious Figures data to rickmorty_characters/Religious_Figures.json
# Saved Reverse Giraffe data to rickmorty_characters/Reverse_Giraffe.json
# Saved Reverse Rick Outrage data to rickmorty_characters/Reverse_Rick_Outrage.json
# Saved Revolio Clockberg, Jr. data to rickmorty_characters/Revolio_Clockberg,_Jr..json
# Saved Rhett Caan data to rickmorty_characters/Rhett_Caan.json
# Saved Ricardo Montoya data to rickmorty_characters/Ricardo_Montoya.json
# Saved Richard data to rickmorty_characters/Richard.json
# Saved Rick D. Sanchez III data to rickmorty_characters/Rick_D._Sanchez_III.json
# Saved Rick Guilt Rick data to rickmorty_characters/Rick_Guilt_Rick.json
# Saved Rick Prime data to rickmorty_characters/Rick_Prime.json
# Saved Rick Prime (Council of Ricks) data to rickmorty_characters/Rick_Prime_(Council_of_Ricks).json
# Saved Rick Sanchez data to rickmorty_characters/Rick_Sanchez.json
# Saved Rick Sanchez (5126) data to rickmorty_characters/Rick_Sanchez_(5126).json
# Saved Rick Sanchez (C-132) data to rickmorty_characters/Rick_Sanchez_(C-132).json
# Saved Rick Sanchez (D-99) data to rickmorty_characters/Rick_Sanchez_(D-99).json
# Saved Rick Sanchez (Evil Rick's Target Dimension) data to rickmorty_characters/Rick_Sanchez_(Evil_Rick's_Target_Dimension).json
# Saved Rick Sanchez (J-22) data to rickmorty_characters/Rick_Sanchez_(J-22).json
# Saved Rick Sanchez (J19α7) data to rickmorty_characters/Rick_Sanchez_(J19α7).json
# Saved Rick Sanchez (K-22) data to rickmorty_characters/Rick_Sanchez_(K-22).json
# Saved Rick Sanchez (Parmesan Dimension) data to rickmorty_characters/Rick_Sanchez_(Parmesan_Dimension).json
# Saved Rick Sanchez (C-131) data to rickmorty_characters/Rick_Sanchez_(C-131).json
# Saved Rick's Father data to rickmorty_characters/Rick's_Father.json
# Saved Rick's Foal data to rickmorty_characters/Rick's_Foal.json
# Saved Rick's friends data to rickmorty_characters/Rick's_friends.json
# Saved RickBot data to rickmorty_characters/RickBot.json
# Saved Ricktiminus Sancheziminius data to rickmorty_characters/Ricktiminus_Sancheziminius.json
# Saved Rick Jerry data to rickmorty_characters/Rick_Jerry.json
# Saved Riq IV data to rickmorty_characters/Riq_IV.json
# Saved Risotto Groupon data to rickmorty_characters/Risotto_Groupon.json
# Saved Robert data to rickmorty_characters/Robert.json
# Saved Robobros data to rickmorty_characters/Robobros.json
# Saved Robot Morty data to rickmorty_characters/Robot_Morty.json
# Saved Robot Rick data to rickmorty_characters/Robot_Rick.json
# Saved Robot Soldiers data to rickmorty_characters/Robot_Soldiers.json
# Saved Roger data to rickmorty_characters/Roger.json
# Saved Roger Wayne Marder data to rickmorty_characters/Roger_Wayne_Marder.json
# Saved Ron Benson data to rickmorty_characters/Ron_Benson.json
# Saved Rose data to rickmorty_characters/Rose.json
# Saved Roy Parsons data to rickmorty_characters/Roy_Parsons.json
# Saved Ruben data to rickmorty_characters/Ruben.json
# Saved Running Bird data to rickmorty_characters/Running_Bird.json
# Saved Rurtaugh data to rickmorty_characters/Rurtaugh.json
# Saved Salesman Rick data to rickmorty_characters/Salesman_Rick.json
# Saved Samantha data to rickmorty_characters/Samantha.json
# Saved Sanchez Family data to rickmorty_characters/Sanchez_Family.json
# Saved Scary Brandon data to rickmorty_characters/Scary_Brandon.json
# Saved Scary Glenn data to rickmorty_characters/Scary_Glenn.json
# Saved Scary Melissa data to rickmorty_characters/Scary_Melissa.json
# Saved Scary Terry data to rickmorty_characters/Scary_Terry.json
# Saved Schlami data to rickmorty_characters/Schlami.json
# Saved Scroopy Noopers data to rickmorty_characters/Scroopy_Noopers.json
# Saved Scropon (Ricksy Business) data to rickmorty_characters/Scropon_(Ricksy_Business).json
# Saved Scrotians data to rickmorty_characters/Scrotians.json
# Saved SEAL Team Ricks data to rickmorty_characters/SEAL_Team_Ricks.json
# Saved Self-Congratulatory Jerry data to rickmorty_characters/Self-Congratulatory_Jerry.json
# Saved Self-Referential Six data to rickmorty_characters/Self-Referential_Six.json
# Saved Self-Referential Six data to rickmorty_characters/Self-Referential_Six.json
# Saved Semosites data to rickmorty_characters/Semosites.json
# Saved Severnians data to rickmorty_characters/Severnians.json
# Saved Shadow Council of Ricks data to rickmorty_characters/Shadow_Council_of_Ricks.json
# Saved Sheikh Rick data to rickmorty_characters/Sheikh_Rick.json
# Saved Shimshamians data to rickmorty_characters/Shimshamians.json
# Saved Shleemypants data to rickmorty_characters/Shleemypants.json
# Saved Shmlamantha Shmlicelli data to rickmorty_characters/Shmlamantha_Shmlicelli.json
# Saved Shmlangela Shmlobinson-Shmlower data to rickmorty_characters/Shmlangela_Shmlobinson-Shmlower.json
# Saved Shmlona Shmlobinson data to rickmorty_characters/Shmlona_Shmlobinson.json
# Saved Shmlonathan Shmlower data to rickmorty_characters/Shmlonathan_Shmlower.json
# Saved Shmlony Shmlicelli data to rickmorty_characters/Shmlony_Shmlicelli.json
# Saved Shmooglite Runner data to rickmorty_characters/Shmooglite_Runner.json
# Saved Shnoopy Bloopers data to rickmorty_characters/Shnoopy_Bloopers.json
# Saved Shrimp Rick data to rickmorty_characters/Shrimp_Rick.json
# Saved Shrimply Pibbles data to rickmorty_characters/Shrimply_Pibbles.json
# Saved Simon data to rickmorty_characters/Simon.json
# Saved Simple Rick data to rickmorty_characters/Simple_Rick.json
# Saved Simulation Morty data to rickmorty_characters/Simulation_Morty.json
# Saved Sinistar-7 data to rickmorty_characters/Sinistar-7.json
# Saved Sleepy Gary data to rickmorty_characters/Sleepy_Gary.json
# Saved Slick Morty data to rickmorty_characters/Slick_Morty.json
# Saved Slippery Stair data to rickmorty_characters/Slippery_Stair.json
# Saved Slow Mobius data to rickmorty_characters/Slow_Mobius.json
# Saved Slow Mobius's daughter data to rickmorty_characters/Slow_Mobius's_daughter.json
# Saved Slow Mobius's son data to rickmorty_characters/Slow_Mobius's_son.json
# Saved Slow Mobius's wife data to rickmorty_characters/Slow_Mobius's_wife.json
# Saved Slow Rick data to rickmorty_characters/Slow_Rick.json
# Saved Smarkians data to rickmorty_characters/Smarkians.json
# Saved Smith Family data to rickmorty_characters/Smith_Family.json
# Saved Snuffles data to rickmorty_characters/Snuffles.json
# Saved Solicitor Rick data to rickmorty_characters/Solicitor_Rick.json
# Saved Space Beth (Parmesan Dimension) data to rickmorty_characters/Space_Beth_(Parmesan_Dimension).json
# Saved Space Cruiser data to rickmorty_characters/Space_Cruiser.json
# Saved Space Jam Morty data to rickmorty_characters/Space_Jam_Morty.json
# Saved Space Jam Rick data to rickmorty_characters/Space_Jam_Rick.json
# Saved Space Snake data to rickmorty_characters/Space_Snake.json
# Saved Sperm Queen data to rickmorty_characters/Sperm_Queen.json
# Saved Squanchy data to rickmorty_characters/Squanchy.json
# Saved Squeeb data to rickmorty_characters/Squeeb.json
# Saved Stacy data to rickmorty_characters/Stacy.json
# Saved Stealy data to rickmorty_characters/Stealy.json
# Saved Steve data to rickmorty_characters/Steve.json
# Saved Steve (Mortyplicity) data to rickmorty_characters/Steve_(Mortyplicity).json
# Saved Steven Phillips data to rickmorty_characters/Steven_Phillips.json
# Saved Sticky data to rickmorty_characters/Sticky.json
# Scraping page: https://rickandmorty.fandom.com/wiki/Category:Characters?from=Story+Lord
# Saved Story Lord data to rickmorty_characters/Story_Lord.json
# Saved Story Train Characters data to rickmorty_characters/Story_Train_Characters.json
# Saved Stu data to rickmorty_characters/Stu.json
# Saved Subject One data to rickmorty_characters/Subject_One.json
# Saved Submarine Nazi data to rickmorty_characters/Submarine_Nazi.json
# Saved Summer Smith data to rickmorty_characters/Summer_Smith.json
# Saved Summer Smith (304-X) data to rickmorty_characters/Summer_Smith_(304-X).json
# Saved Summer Smith (5126) data to rickmorty_characters/Summer_Smith_(5126).json
# Saved Summer Smith (C-1239) data to rickmorty_characters/Summer_Smith_(C-1239).json
# Saved Summer Smith (C-132) data to rickmorty_characters/Summer_Smith_(C-132).json
# Saved Summer Smith (C-290) data to rickmorty_characters/Summer_Smith_(C-290).json
# Saved Summer Smith Prime data to rickmorty_characters/Summer_Smith_Prime.json
# Saved Summer Smith (Evil Rick's Target Dimension) data to rickmorty_characters/Summer_Smith_(Evil_Rick's_Target_Dimension).json
# Saved Summer Smith (Goldenfold's Dream) data to rickmorty_characters/Summer_Smith_(Goldenfold's_Dream).json
# Saved Summer Smith (Parmesan Dimension) data to rickmorty_characters/Summer_Smith_(Parmesan_Dimension).json
# Saved Summer Smith (S-223) data to rickmorty_characters/Summer_Smith_(S-223).json
# Saved Summer's Boyfriend data to rickmorty_characters/Summer's_Boyfriend.json
# Saved Summer's Girlfriend data to rickmorty_characters/Summer's_Girlfriend.json
# Saved Superheroes data to rickmorty_characters/Superheroes.json
# Saved Supernova data to rickmorty_characters/Supernova.json
# Saved Supreme Guard Ricks data to rickmorty_characters/Supreme_Guard_Ricks.json
# Saved Taddy Mason data to rickmorty_characters/Taddy_Mason.json
# Saved Tag-Man data to rickmorty_characters/Tag-Man.json
# Saved Taint Washer data to rickmorty_characters/Taint_Washer.json
# Saved Talking Cat data to rickmorty_characters/Talking_Cat.json
# Saved Tammy Guterman data to rickmorty_characters/Tammy_Guterman.json
# Saved Tanya Radcliffe data to rickmorty_characters/Tanya_Radcliffe.json
# Saved Task Force Alpha data to rickmorty_characters/Task_Force_Alpha.json
# Saved Teacher Rick data to rickmorty_characters/Teacher_Rick.json
# Saved Terry data to rickmorty_characters/Terry.json
# Saved Terryfolds data to rickmorty_characters/Terryfolds.json
# Saved The Garage data to rickmorty_characters/The_Garage.json
# Saved The Little Girl data to rickmorty_characters/The_Little_Girl.json
# Saved The One True Morty data to rickmorty_characters/The_One_True_Morty.json
# Saved The Pope data to rickmorty_characters/The_Pope.json
# Saved The President (Ice Cream Universe) data to rickmorty_characters/The_President_(Ice_Cream_Universe).json
# Saved The President of the Miniverse data to rickmorty_characters/The_President_of_the_Miniverse.json
# Saved The Queen data to rickmorty_characters/The_Queen.json
# Saved The Scientist Formerly Known as Rick data to rickmorty_characters/The_Scientist_Formerly_Known_as_Rick.json
# Saved The Tyrannosaurus data to rickmorty_characters/The_Tyrannosaurus.json
# Saved The Wizard data to rickmorty_characters/The_Wizard.json
# Saved Thomas Lipnip data to rickmorty_characters/Thomas_Lipnip.json
# Saved Three Unknown Things data to rickmorty_characters/Three_Unknown_Things.json
# Saved Ticktock data to rickmorty_characters/Ticktock.json
# Saved Time Bird data to rickmorty_characters/Time_Bird.json
# Saved Tina-Teers data to rickmorty_characters/Tina-Teers.json
# Saved Tinkles data to rickmorty_characters/Tinkles.json
# Saved Tiny Rick data to rickmorty_characters/Tiny_Rick.json
# Saved Toby Matthews data to rickmorty_characters/Toby_Matthews.json
# Saved Todd Crystal data to rickmorty_characters/Todd_Crystal.json
# Saved Tom (Observer) data to rickmorty_characters/Tom_(Observer).json
# Saved Tommy's Clone data to rickmorty_characters/Tommy's_Clone.json
# Saved Tony's Wife data to rickmorty_characters/Tony's_Wife.json
# Saved Tophat Jones data to rickmorty_characters/Tophat_Jones.json
# Saved Tortured Mortys data to rickmorty_characters/Tortured_Mortys.json
# Saved Tough Rat data to rickmorty_characters/Tough_Rat.json
# Saved Toxic Morty data to rickmorty_characters/Toxic_Morty.json
# Saved Toxic Rick data to rickmorty_characters/Toxic_Rick.json
# Saved Traflorkians data to rickmorty_characters/Traflorkians.json
# Saved Trandor data to rickmorty_characters/Trandor.json
# Saved Tricia Lange data to rickmorty_characters/Tricia_Lange.json
# Saved Trunk Morty data to rickmorty_characters/Trunk_Morty.json
# Saved Trunk People data to rickmorty_characters/Trunk_People.json
# Saved Truth Tortoise data to rickmorty_characters/Truth_Tortoise.json
# Saved Tumblorkians data to rickmorty_characters/Tumblorkians.json
# Saved Tusked Assassin data to rickmorty_characters/Tusked_Assassin.json
# Saved Two Crows data to rickmorty_characters/Two_Crows.json
# Saved Two Guys with Handlebar Mustaches data to rickmorty_characters/Two_Guys_with_Handlebar_Mustaches.json
# Saved Uncle Steve data to rickmorty_characters/Uncle_Steve.json
# Saved Unity data to rickmorty_characters/Unity.json
# Saved Unknown Fate data to rickmorty_characters/Unknown_Fate.json
# Saved Unmuscular Michaels data to rickmorty_characters/Unmuscular_Michaels.json
# Saved Unnamed air woman data to rickmorty_characters/Unnamed_air_woman.json
# Saved Unseen Characters data to rickmorty_characters/Unseen_Characters.json
# Saved Vampire Master data to rickmorty_characters/Vampire_Master.json
# Saved Vance Maximus data to rickmorty_characters/Vance_Maximus.json
# Saved Ventriloquiver data to rickmorty_characters/Ventriloquiver.json
# Saved Vermigurber data to rickmorty_characters/Vermigurber.json
# Saved Veronica Ann Bennet data to rickmorty_characters/Veronica_Ann_Bennet.json
# Saved Visor Rick data to rickmorty_characters/Visor_Rick.json
# Saved Voltamatron data to rickmorty_characters/Voltamatron.json
# Saved Vulvorvians data to rickmorty_characters/Vulvorvians.json
# Saved Warlord of Titan data to rickmorty_characters/Warlord_of_Titan.json
# Saved Wasp Rick data to rickmorty_characters/Wasp_Rick.json
# Saved Wasp Summer data to rickmorty_characters/Wasp_Summer.json
# Saved Wedding Bartender data to rickmorty_characters/Wedding_Bartender.json
# Saved Western Morty data to rickmorty_characters/Western_Morty.json
# Saved Western Rick data to rickmorty_characters/Western_Rick.json
# Saved Wharborgarbors data to rickmorty_characters/Wharborgarbors.json
# Saved Woman Rick data to rickmorty_characters/Woman_Rick.json
# Saved Worldender data to rickmorty_characters/Worldender.json
# Saved Xing Ho data to rickmorty_characters/Xing_Ho.json
# Saved Xorjhans data to rickmorty_characters/Xorjhans.json
# Saved Yaarb data to rickmorty_characters/Yaarb.json
# Saved Yellow Headed Doctor data to rickmorty_characters/Yellow_Headed_Doctor.json
# Saved Yellow Shirt Rick data to rickmorty_characters/Yellow_Shirt_Rick.json
# Saved Zarbadar Gloonch data to rickmorty_characters/Zarbadar_Gloonch.json
# Saved Zarbadar's Mytholog data to rickmorty_characters/Zarbadar's_Mytholog.json
# Saved Zeep Xanflorp data to rickmorty_characters/Zeep_Xanflorp.json
# Saved Zerillians data to rickmorty_characters/Zerillians.json
# Saved Zeta Alpha Rick data to rickmorty_characters/Zeta_Alpha_Rick.json
